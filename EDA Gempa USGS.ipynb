# %% [markdown]
# # Exploratory Data Analisys (GEMPA USGS)

# %%
import pandas as pd

data =  pd.read_csv ('Downloads/USGS_10YearsData.csv')
data.head(5)
# Out:
#                        time  latitude  longitude  depth  mag magType    nst  \
# 0  2009-08-01T07:41:43.820Z   -42.009    -89.713   10.0  5.1     mwc   13.0
# 1  2009-08-01T09:45:50.760Z    37.576    141.789   47.4  5.0     mwc  211.0
# 2  2009-08-01T13:33:29.950Z   -56.234   -124.296   10.0  6.1     mwc   66.0
# 3  2009-08-01T22:00:50.480Z    -9.187    123.184  113.0  5.3     mwc  125.0
# 4  2009-08-01T23:07:01.990Z   -12.097    -75.406  101.3  5.2     mwc  190.0
#
#      gap  dmin   rms  ...                   updated  \
# 0  103.6   NaN  1.42  ...  2016-11-10T02:15:34.586Z
# 1   67.0   NaN  0.75  ...  2016-11-10T02:15:35.104Z
# 2   35.8   NaN  1.13  ...  2016-11-10T02:15:35.681Z
# 3   34.5   NaN  1.15  ...  2016-11-10T02:15:36.702Z
# 4   41.8   NaN  0.91  ...  2016-11-10T02:15:37.185Z
#
#                                   place        type horizontalError  \
# 0            southeast of Easter Island  earthquake             NaN
# 1  near the east coast of Honshu, Japan  earthquake             NaN
# 2            southern East Pacific Rise  earthquake             NaN
# 3               Timor region, Indonesia  earthquake             NaN
# 4                          central Peru  earthquake             NaN
#
#   depthError  magError  magNst    status  locationSource magSource
# 0        NaN       NaN     NaN  reviewed              us      gcmt
# 1        4.8       NaN     NaN  reviewed              us      gcmt
# 2        NaN       NaN     NaN  reviewed              us        us
# 3        NaN       NaN     NaN  reviewed              us      gcmt
# 4        5.9       NaN     NaN  reviewed              us      gcmt
#
# [5 rows x 22 columns]

# %%
data.tail(5)
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 18583  2019-07-31T08:29:23.191Z   59.8892   144.6831   10.00  5.0      mb
# 18584  2019-07-31T09:45:28.729Z   56.1341   164.2862   10.00  5.0     mww
# 18585  2019-07-31T15:02:33.853Z  -16.1985   167.9982  181.00  6.6     mww
# 18586  2019-07-31T18:35:53.399Z   -0.7656   133.2522   41.78  5.2     mww
# 18587  2019-07-31T19:11:44.629Z  -16.2230   167.9933  188.78  5.0      mb
#
#        nst    gap   dmin   rms  ...                   updated  \
# 18583  NaN   34.0  3.098  0.93  ...  2019-09-04T06:16:11.040Z
# 18584  NaN  112.0  4.523  0.65  ...  2019-09-13T16:40:47.040Z
# 18585  NaN   30.0  6.024  0.99  ...  2019-08-20T23:11:32.445Z
# 18586  NaN   41.0  2.362  0.90  ...  2019-08-19T19:10:04.632Z
# 18587  NaN   62.0  5.999  0.77  ...  2019-08-19T19:17:58.040Z
#
#                                           place        type horizontalError  \
# 18583                96km NE of Okhotsk, Russia  earthquake             7.8
# 18584  112km E of Ust'-Kamchatsk Staryy, Russia  earthquake             7.9
# 18585               62km E of Lakatoro, Vanuatu  earthquake             7.6
# 18586            93km W of Manokwari, Indonesia  earthquake             7.5
# 18587               62km E of Lakatoro, Vanuatu  earthquake             8.1
#
#       depthError  magError  magNst    status  locationSource magSource
# 18583        0.9     0.025   527.0  reviewed              us        us
# 18584        1.8     0.073    18.0  reviewed              us        us
# 18585        1.8     0.038    65.0  reviewed              us        us
# 18586        5.6     0.086    13.0  reviewed              us        us
# 18587        4.6     0.084    45.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18588 entries, 0 to 18587
# Data columns (total 22 columns):
# time               18588 non-null object
# latitude           18588 non-null float64
# longitude          18588 non-null float64
# depth              18588 non-null float64
# mag                18588 non-null float64
# magType            18588 non-null object
# nst                8668 non-null float64
# gap                18273 non-null float64
# dmin               9709 non-null float64
# rms                18115 non-null float64
# net                18588 non-null object
# id                 18588 non-null object
# updated            18588 non-null object
# place              18588 non-null object
# type               18588 non-null object
# horizontalError    8171 non-null float64
# depthError         13637 non-null float64
# magError           7917 non-null float64
# magNst             10988 non-null float64
# status             18588 non-null object
# locationSource     18588 non-null object
# magSource          18588 non-null object
# dtypes: float64(12), object(10)
# memory usage: 3.1+ MB

# %%
data.isnull().sum()
# Out:
# time                   0
# latitude               0
# longitude              0
# depth                  0
# mag                    0
# magType                0
# nst                 9920
# gap                  315
# dmin                8879
# rms                  473
# net                    0
# id                     0
# updated                0
# place                  0
# type                   0
# horizontalError    10417
# depthError          4951
# magError           10671
# magNst              7600
# status                 0
# locationSource         0
# magSource              0
# dtype: int64

# %%
data.drop('latitude', axis=1, inplace=True)
data.drop('longitude', axis=1, inplace=True)
data.drop('dmin', axis=1, inplace=True)
data.drop('nst', axis=1, inplace=True)
data.drop('gap', axis=1, inplace=True)
data.drop('net', axis=1, inplace=True)
data.drop('id', axis=1, inplace=True)
data.drop('updated', axis=1, inplace=True)
data.drop('horizontalError', axis=1, inplace=True)
data.drop('depthError', axis=1, inplace=True)
data.drop('magError', axis=1, inplace=True)
data.drop('magNst', axis=1, inplace=True)
data.drop('status', axis=1, inplace=True)
data.drop('locationSource', axis=1, inplace=True)
data.drop('magSource', axis=1, inplace=True)
data.drop('rms', axis=1, inplace=True)

# %%
data.head(5)
# Out:
#                        time  depth  mag magType  \
# 0  2009-08-01T07:41:43.820Z   10.0  5.1     mwc
# 1  2009-08-01T09:45:50.760Z   47.4  5.0     mwc
# 2  2009-08-01T13:33:29.950Z   10.0  6.1     mwc
# 3  2009-08-01T22:00:50.480Z  113.0  5.3     mwc
# 4  2009-08-01T23:07:01.990Z  101.3  5.2     mwc
#
#                                   place        type
# 0            southeast of Easter Island  earthquake
# 1  near the east coast of Honshu, Japan  earthquake
# 2            southern East Pacific Rise  earthquake
# 3               Timor region, Indonesia  earthquake
# 4                          central Peru  earthquake

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18588 entries, 0 to 18587
# Data columns (total 6 columns):
# time       18588 non-null object
# depth      18588 non-null float64
# mag        18588 non-null float64
# magType    18588 non-null object
# place      18588 non-null object
# type       18588 non-null object
# dtypes: float64(2), object(4)
# memory usage: 871.4+ KB

# %%
# Merubah kolom date menjadi format waktu
data['time'] = pd.to_datetime(data['time'])

# Memisahkan data waktu menjadi kolom waktu yang terpisah
data['Year'] = data.time.dt.year
data['Month'] = data.time.dt.month
data['Day'] = data.time.dt.day
data['Hour'] = data.time.dt.hour
data['Minute'] = data.time.dt.minute
data['Weekday'] = data.time.dt.dayofweek
# Memisahkan data place menjadi kolom Kota dan Negara
data['City'] = data['place'].str.rpartition(',')[0]
data['State'] = data['place'].str.rpartition(',')[2]

# %%
data.head(5)
# Out:
#    depth  mag magType        type  Year  Month  Day  Hour  Minute  Weekday  \
# 0   10.0  5.1     mwc  earthquake  2009      8    1     7      41        5
# 1   47.4  5.0     mwc  earthquake  2009      8    1     9      45        5
# 2   10.0  6.1     mwc  earthquake  2009      8    1    13      33        5
# 3  113.0  5.3     mwc  earthquake  2009      8    1    22       0        5
# 4  101.3  5.2     mwc  earthquake  2009      8    1    23       7        5
#
#                             City                       State
# 0                                 southeast of Easter Island
# 1  near the east coast of Honshu                       Japan
# 2                                 southern East Pacific Rise
# 3                   Timor region                   Indonesia
# 4                                               central Peru

# %%
data.drop('time', axis=1, inplace=True)
data.drop('place', axis=1, inplace=True)

# %%
data.head()
# Out:
#    depth  mag magType        type  Year  Month  Day  Hour  Minute  Weekday  \
# 0   10.0  5.1     mwc  earthquake  2009      8    1     7      41        5
# 1   47.4  5.0     mwc  earthquake  2009      8    1     9      45        5
# 2   10.0  6.1     mwc  earthquake  2009      8    1    13      33        5
# 3  113.0  5.3     mwc  earthquake  2009      8    1    22       0        5
# 4  101.3  5.2     mwc  earthquake  2009      8    1    23       7        5
#
#                             City                       State
# 0                                 southeast of Easter Island
# 1  near the east coast of Honshu                       Japan
# 2                                 southern East Pacific Rise
# 3                   Timor region                   Indonesia
# 4                                               central Peru

# %%
data.Month.value_counts()
# Out:
# 3     2008
# 2     1640
# 12    1624
# 9     1600
# 4     1546
# 11    1517
# 10    1504
# 8     1485
# 1     1484
# 7     1461
# 5     1420
# 6     1299
# Name: Month, dtype: int64

# %%
data.City.value_counts()
# Out:
#                                          5536
# near the east coast of Honshu             455
# off the east coast of Honshu              407
# New Britain region                        130
# offshore Bio-Bio                          117
# Bonin Islands                             112
# Mindanao                                   68
# eastern New Guinea region                  62
# Kermadec Islands                           61
# Bio-Bio                                    57
# Andreanof Islands, Aleutian Islands        57
# offshore Maule                             56
# Loyalty Islands                            55
# offshore Valparaiso                        54
# Izu Islands                                54
# southern Sumatra                           54
# eastern Honshu                             50
# Kepulauan Barat Daya                       49
# Fox Islands, Aleutian Islands              49
# Libertador General Bernardo O'Higgins      48
# New Ireland region                         48
# near the north coast of Papua              46
# Kepulauan Mentawai region                  45
# offshore Libertador O'Higgins              45
# Bougainville region                        44
# Halmahera                                  40
# Ryukyu Islands                             38
# northern Sumatra                           36
# Andaman Islands                            34
# 5km WSW of Volcano                         33
#                                          ...
# 92km WSW of Kirakira                        1
# 53km SSE of Korsakov                        1
# 68km NW of Talcahuano                       1
# 88km S of Kavieng                           1
# 94km ESE of Caburan                         1
# 70km SE of Kirakira                         1
# 98km E of Visokoi Island                    1
# 143km WSW of Naze                           1
# 30km ESE of Lakatoro                        1
# 178km N of Flying Fish Cove                 1
# 51km E of Shizunai                          1
# 28km SW of Nagarote                         1
# 88km NNE of Tocopilla                       1
# 84km N of Minab                             1
# 46km ESE of Blenheim                        1
# 265km S of `Ohonua                          1
# 52km E of Bristol Island                    1
# 68km ESE of `Ohonua                         1
# 43km E of Tobelo                            1
# 53km N of Claveria                          1
# 101km SW of Paredon                         1
# 46km W of Kigorobya                         1
# 151km SSW of Kokopo                         1
# 31km SSE of Mawlaik                         1
# 1km WNW of Hualian                          1
# 108km ENE of Ile Hunter                     1
# 168km SSE of Mata-Utu                       1
# 88km SSW of Ndoi Island                     1
# 73km SW of Bristol Island                   1
# 1km NNE of Guiling                          1
# Name: City, Length: 8820, dtype: int64

# %%
data.tail(5)
# Out:
#         depth  mag magType        type  Year  Month  Day  Hour  Minute  \
# 18583   10.00  5.0      mb  earthquake  2019      7   31     8      29
# 18584   10.00  5.0     mww  earthquake  2019      7   31     9      45
# 18585  181.00  6.6     mww  earthquake  2019      7   31    15       2
# 18586   41.78  5.2     mww  earthquake  2019      7   31    18      35
# 18587  188.78  5.0      mb  earthquake  2019      7   31    19      11
#
#        Weekday                              City       State
# 18583        2                96km NE of Okhotsk      Russia
# 18584        2  112km E of Ust'-Kamchatsk Staryy      Russia
# 18585        2                62km E of Lakatoro     Vanuatu
# 18586        2               93km W of Manokwari   Indonesia
# 18587        2                62km E of Lakatoro     Vanuatu

# %%
data.type.value_counts()
# Out:
# earthquake           18530
# volcanic eruption       54
# nuclear explosion        4
# Name: type, dtype: int64

# %%
data.head(5)
# Out:
#    depth  mag magType        type  Year  Month  Day  Hour  Minute  Weekday  \
# 0   10.0  5.1     mwc  earthquake  2009      8    1     7      41        5
# 1   47.4  5.0     mwc  earthquake  2009      8    1     9      45        5
# 2   10.0  6.1     mwc  earthquake  2009      8    1    13      33        5
# 3  113.0  5.3     mwc  earthquake  2009      8    1    22       0        5
# 4  101.3  5.2     mwc  earthquake  2009      8    1    23       7        5
#
#                             City                       State
# 0                                 southeast of Easter Island
# 1  near the east coast of Honshu                       Japan
# 2                                 southern East Pacific Rise
# 3                   Timor region                   Indonesia
# 4                                               central Peru

# %%
data.Year.value_counts()
# Out:
# 2011    2693
# 2010    2395
# 2018    1806
# 2014    1735
# 2016    1697
# 2012    1679
# 2013    1602
# 2015    1559
# 2017    1558
# 2019     962
# 2009     902
# Name: Year, dtype: int64

# %%
data.mag.value_counts()
# Out:
# 5.00    4569
# 5.10    3395
# 5.20    2483
# 5.30    1835
# 5.40    1296
# 5.50    1047
# 5.60     822
# 5.70     642
# 5.80     521
# 5.90     408
# 6.00     339
# 6.10     245
# 6.30     169
# 6.20     169
# 6.40     108
# 6.50      95
# 6.60      82
# 6.70      61
# 6.90      53
# 6.80      46
# 7.10      32
# 7.00      31
# 7.30      21
# 7.20      15
# 7.50      13
# 7.80      10
# 7.60      10
# 7.70       9
# 7.40       9
# 7.90       6
#         ...
# 8.30       2
# 5.09       2
# 5.08       2
# 8.00       2
# 5.06       2
# 5.41       1
# 5.26       1
# 5.69       1
# 5.43       1
# 5.88       1
# 5.32       1
# 6.02       1
# 5.71       1
# 5.58       1
# 5.22       1
# 5.42       1
# 5.34       1
# 5.72       1
# 9.10       1
# 5.44       1
# 5.28       1
# 8.60       1
# 5.38       1
# 5.01       1
# 8.80       1
# 8.10       1
# 5.73       1
# 5.64       1
# 5.35       1
# 5.54       1
# Name: mag, Length: 64, dtype: int64

# %%
data.depth.value_counts()
# Out:
# 10.00     5830
# 35.00     1160
# 20.00      125
# 8.00       103
# 12.00      102
# 9.00       100
# 11.00       81
# 15.00       81
# 14.00       80
# 13.00       79
# 16.00       64
# 18.00       60
# 17.00       59
# 19.00       54
# 21.00       53
# 7.00        51
# 29.00       51
# 5.00        50
# 6.00        49
# 22.00       49
# 28.00       45
# 30.00       41
# 34.00       38
# 32.00       37
# 26.00       37
# 24.00       36
# 27.00       35
# 23.00       34
# 33.00       33
# 31.00       32
#           ...
# 251.00       1
# 37.54        1
# 37.71        1
# 591.20       1
# 219.00       1
# 44.95        1
# 68.75        1
# 96.79        1
# 34.96        1
# 129.82       1
# 39.16        1
# 28.89        1
# 194.22       1
# 61.85        1
# 133.80       1
# 23.93        1
# 43.53        1
# 8.64         1
# 25.35        1
# 18.94        1
# 91.80        1
# 404.82       1
# 38.71        1
# 433.00       1
# 191.00       1
# 110.90       1
# 34.25        1
# 43.52        1
# 568.79       1
# 38.23        1
# Name: depth, Length: 5287, dtype: int64

# %%
data.magType.value_counts()
# Out:
# mb       8547
# mww      4697
# mwc      3760
# mwb      1053
# mwr       289
# mw        185
# ml         38
# ms          9
# m           5
# ms_20       2
# Ml          1
# Mw          1
# Md          1
# Name: magType, dtype: int64

# %%
data.State.value_counts()
# Out:
#  Indonesia                                       1828
#  Japan                                           1611
#  Papua New Guinea                                1203
#  Chile                                           1121
#  Philippines                                      589
#  New Zealand                                      572
#  Alaska                                           524
#  Solomon Islands                                  511
#  Tonga                                            432
#  Russia                                           388
# Vanuatu                                           331
#  Mexico                                           322
# Tonga                                             306
#  New Caledonia                                    297
#  Vanuatu                                          270
#  Fiji                                             245
#  China                                            221
#  Japan region                                     219
# Pacific-Antarctic Ridge                           186
# Fiji region                                       175
#  South Georgia and the South Sandwich Islands     161
#  Northern Mariana Islands                         159
# Santa Cruz Islands                                159
#  Peru                                             151
# South Sandwich Islands region                     141
#  Argentina                                        141
# Kermadec Islands region                           130
#  India                                            126
# Kuril Islands                                     124
# south of the Fiji Islands                         113
#                                                  ...
# off the coast of northern Peru                      1
# Bay of Bengal                                       1
# Turkey-Iran border region                           1
# near the southeast coast of Australia               1
# central Mediterranean Sea                           1
# southwestern Atlantic Ocean                         1
#  Eritrea                                            1
# Northern California                                 1
# Afghanistan-Tajikistan-Pakistan region              1
# Black Sea                                           1
#  Niue                                               1
# Bangladesh                                          1
# Samoa Islands                                       1
#  Spain                                              1
#  New Mexico                                         1
# Kashmir-India border region                         1
# Ross Sea                                            1
# Mozambique                                          1
# southern Italy                                      1
#  Mongolia                                           1
# South Napa                                          1
# Northwest of Australia                              1
# Red Sea                                             1
# central Afghanistan                                 1
#  Norway                                             1
# off the coast of Northern California                1
# Timor region                                        1
# East of Severnaya Zemlya                            1
# Off the coast of Central America                    1
# North of Macquarie Island                           1
# Name: State, Length: 457, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

year_counts = data.State.value_counts()


plt.figure(figsize=(15,10))
sns.barplot(year_counts.index, year_counts.values)
plt.title('Frekuensi Gempa Tahunan di Seluruh Dunia 1998-2019')
plt.xlabel('Tahun', fontsize=14)
plt.ylabel('Frekuensi Gempa', fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %%
from pandas import DataFrame

indonesia = data.loc[data.State == ' Indonesia']
indonesia.head(5)
# Out:
#     depth  mag magType        type  Year  Month  Day  Hour  Minute  Weekday  \
# 3   113.0  5.3     mwc  earthquake  2009      8    1    22       0        5
# 5    20.0  6.1     mwc  earthquake  2009      8    2     8      54        6
# 57   54.3  5.0     mwc  earthquake  2009      8   15     4       4        5
# 58  160.3  5.3     mwc  earthquake  2009      8   15    12      30        5
# 60   98.3  5.0     mwc  earthquake  2009      8   15    16      28        5
#
#                              City       State
# 3                    Timor region   Indonesia
# 5   near the north coast of Papua   Indonesia
# 57               northern Sumatra   Indonesia
# 58             Minahasa, Sulawesi   Indonesia
# 60               Kepulauan Talaud   Indonesia

# %%
data.Year.value_counts()
# Out:
# 2011    2693
# 2010    2395
# 2018    1806
# 2014    1735
# 2016    1697
# 2012    1679
# 2013    1602
# 2015    1559
# 2017    1558
# 2019     962
# 2009     902
# Name: Year, dtype: int64

# %%
dunia = data.Year.value_counts()


plt.figure(figsize=(15,10))
sns.barplot(dunia.index, dunia.values)
plt.title('Frekuensi Gempa Tahunan di Dunia (2009-2019)', fontsize=30)
plt.xlabel('Tahun', fontsize=24)
plt.ylabel('Frekuensi Gempa', fontsize=24)
plt.show()

# %%
indonesia.Year.value_counts()
# Out:
# 2018    224
# 2010    184
# 2015    180
# 2017    175
# 2014    174
# 2019    170
# 2012    166
# 2011    166
# 2016    156
# 2013    134
# 2009     99
# Name: Year, dtype: int64

# %%
gempa_indonesia = indonesia.Year.value_counts()


plt.figure(figsize=(15,10))
sns.barplot(gempa_indonesia.index, gempa_indonesia.values)
plt.title('Frekuensi Gempa Tahunan di Indonesia (2009-2019)', fontsize=30)
plt.xlabel('Tahun', fontsize=24)
plt.ylabel('Frekuensi Gempa', fontsize=24)
plt.xticks(rotation=90)
plt.show()

# %%
indonesia.mag.mean()
# Out:
# 5.312144420131327

# %%
indonesia.mag.median()
# Out:
# 5.2

# %%
gempa1_indonesia = indonesia.mag.value_counts()


plt.figure(figsize=(15,10))
sns.barplot(gempa1_indonesia.index, gempa1_indonesia.values)
plt.title('Frekuensi Gempa Tahunan di Indonesia')
plt.xlabel('magnitudo', fontsize=14)
plt.ylabel('Frekuensi Gempa', fontsize=14)
plt.xticks(rotation=90)
plt.show()

# %%
indonesia.type.value_counts()
# Out:
# earthquake    1828
# Name: type, dtype: int64

# %%
# most correlated features
corrmat = data.corr()
top_corr_features = corrmat.index[abs(corrmat["mag"])>0.05]
plt.figure(figsize=(10,10))
g = sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
magnitudo = data.loc[data.mag == 9.1]
magnitudo
# Out:
#       depth  mag magType        type  Year  Month  Day  Hour  Minute  Weekday  \
# 3723   29.0  9.1     mww  earthquake  2011      3   11     5      46        4
#
#                               City   State
# 3723  2011 Great Tohoku Earthquake   Japan

# %%
nuklir = data.loc[data.type == 'nuclear explosion']
nuklir
# Out:
#        depth  mag magType               type  Year  Month  Day  Hour  Minute  \
# 7974     0.0  5.1      mb  nuclear explosion  2013      2   12     2      57
# 12579    0.0  5.1      mb  nuclear explosion  2016      1    6     1      30
# 13631    0.0  5.3      mb  nuclear explosion  2016      9    9     0      30
# 15287    0.0  6.3      mb  nuclear explosion  2017      9    3     3      30
#
#        Weekday                      City         State
# 7974         1  24km ENE of Sungjibaegam   North Korea
# 12579        2  21km ENE of Sungjibaegam   North Korea
# 13631        4  23km ENE of Sungjibaegam   North Korea
# 15287        6  21km ENE of Sungjibaegam   North Korea

# %%
vulkanik = data.loc[data.type == 'volcanic eruption']
vulkanik.head(10)
# Out:
#        depth  mag magType               type  Year  Month  Day  Hour  Minute  \
# 16418   0.01  5.0      mw  volcanic eruption  2018      5   17     4      15
# 16420   0.01  5.0      mw  volcanic eruption  2018      5   17    14       4
# 16437   0.01  5.1      mw  volcanic eruption  2018      5   19     9      58
# 16469   0.43  5.1      mw  volcanic eruption  2018      5   26     2      15
# 16479  -0.27  5.3      mw  volcanic eruption  2018      5   29    11      56
# 16484  -0.07  5.4      mw  volcanic eruption  2018      5   30    20      53
# 16489   0.53  5.4      mw  volcanic eruption  2018      6    1    23      37
# 16498   0.58  5.4      mw  volcanic eruption  2018      6    4     1      50
# 16501  -0.83  5.4      mw  volcanic eruption  2018      6    5    14      32
# 16508   0.36  5.4      mw  volcanic eruption  2018      6    7     2       6
#
#        Weekday                City    State
# 16418        3  5km WSW of Volcano   Hawaii
# 16420        3  5km WSW of Volcano   Hawaii
# 16437        5  5km WSW of Volcano   Hawaii
# 16469        5  5km WSW of Volcano   Hawaii
# 16479        1  5km WSW of Volcano   Hawaii
# 16484        2  5km WSW of Volcano   Hawaii
# 16489        4   5km SW of Volcano   Hawaii
# 16498        0  5km WSW of Volcano   Hawaii
# 16501        1  6km WSW of Volcano   Hawaii
# 16508        3  5km WSW of Volcano   Hawaii

# %%
vulkanik2 = vulkanik.City.value_counts()
vulkanik2
# Out:
# 5km WSW of Volcano    33
# 5km SW of Volcano      8
# 6km WSW of Volcano     7
# 4km WSW of Volcano     5
# 4km SW of Volcano      1
# Name: City, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(vulkanik2.index, vulkanik2.values)
plt.title('Gempa Vulkanik berdasarkan Lokasi Titik Gempa (2018)', fontsize=30)
plt.xlabel('Lokasi Gempa Vulkanik', fontsize=24)
plt.ylabel('Frekuensi Gempa', fontsize=24)
plt.xticks(rotation=0)
plt.show()

# %%
indonesia.City.value_counts()
# Out:
# southern Sumatra                 54
# Kepulauan Barat Daya             49
# near the north coast of Papua    46
# Kepulauan Mentawai region        45
# Halmahera                        40
# northern Sumatra                 36
# Kepulauan Talaud                 33
# Sulawesi                         33
# Minahasa, Sulawesi               30
# Papua                            30
# southwest of Sumatra             27
# Java                             25
# south of Java                    24
# Nias region                      24
# Simeulue                         17
# Sunda Strait                     16
# Flores region                    12
# near the south coast of Papua    12
# Seram                            11
# Kepulauan Babar                  11
# Kepulauan Sangihe                10
# Sumbawa region                    9
# Southwest of Sumatra              8
# Kepulauan Tanimbar                7
# Kepulauan Kai                     7
# Ceram Sea                         7
# Kepulauan Batu                    5
# 127km NW of Kota Ternate          4
# south of Sumbawa                  4
# Kepulauan Obi                     4
#                                  ..
# 192km NNE of Tobelo               1
# 116km S of Krajan Tambakrejo      1
# 25km NNE of Ternate               1
# 49km SE of Saparua                1
# 100km SSW of Cigarogol            1
# 111km WSW of Abepura              1
# 55km SE of Atambua                1
# 118km S of Sidorukun              1
# 219km W of Abepura                1
# 52km NNW of Sangiang              1
# 154km SSE of Sinabang             1
# 227km NW of Saumlaki              1
# 4km S of Kendalrejo               1
# 139km SSE of Sinabang             1
# 54km N of Jayapura                1
# 113km NNW of Palu                 1
# 104km ENE of Luwuk                1
# 69km N of Ternate                 1
# 4km ENE of Anyar                  1
# 141km SW of Tual                  1
# 122km WNW of Bengkulu             1
# 32km WSW of Tugu Hilir            1
# 245km WNW of Saumlaki             1
# 2km SE of Belanting               1
# 18km N of Ternate                 1
# 20km E of Watubuku                1
# 16km NNW of Kasiguncu             1
# 78km ESE of Leof                  1
# 280km S of Amahusu                1
# 44km NNW of Kuripan               1
# Name: City, Length: 1143, dtype: int64

# %%
palu = indonesia.loc[indonesia.mag == 7.5]
palu
# Out:
#        depth  mag magType        type  Year  Month  Day  Hour  Minute  \
# 17107   20.0  7.5     mww  earthquake  2018      9   28    10       2
#
#        Weekday            City       State
# 17107        4  70km N of Palu   Indonesia
